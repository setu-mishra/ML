# %% [markdown]
# <a href="https://colab.research.google.com/github/setu-mishra/ML/blob/main/linear_regression_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x = np.array([1, 2, 3, 4]).reshape(-1, 1)
y = np.array([1, 3, 4, 8])



model = LinearRegression()
model.fit(x, y)




intercept = model.intercept_
coefficient = model.coef_[0]
print(f"Intercept (a0): {intercept}")
print(f"Coefficient (a1): {coefficient}")




# Predict y for x = 5
x_new = np.array([[5]])
y_pred = model.predict(x_new)

print(f"Predicted y for x=5: {y_pred[0]}")




# Plot the original data points
plt.scatter(x, y, color='blue', label='Data')

# Plot the regression line
y_line = model.predict(x)
plt.plot(x, y_line, color='red', label='Regression Line')

# Labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()

# Show the plot
plt.show()
# Out:
# Intercept (a0): -1.4999999999999991
# Coefficient (a1): 2.1999999999999997
# Predicted y for x=5: 9.5
